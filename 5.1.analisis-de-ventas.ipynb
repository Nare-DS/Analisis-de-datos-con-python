# %% [markdown]
# # Análisis de ventas
#
# Se facilita una lista de `dict` con datos reales de ventas con las siguientes keys:
#
# * 'Order ID'
# * 'Product'
# * 'Quantity Ordered'
# * 'Price Each
# * 'Order Date'
# * 'Purchase Address'
#
# y values de tipo `str` en todos los casos:

# %%
import math
import pickle5 as pickle 

with open('sales_data.pickle', 'rb') as handle:
    sales_data = pickle.load(handle)

# %%
! pip install pickle5

# %%
len(sales_data)
# Out:
# 186850

# %%
sales = sales_data[0:100]
print(sales)
# Out:
# [{'Order ID': '209921', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/23/19 19:34', 'Purchase Address': '950 Walnut St, Portland, ME 04101'}, {'Order ID': '209922', 'Product': 'Macbook Pro Laptop', 'Quantity Ordered': '1', 'Price Each': '1700.0', 'Order Date': '06/30/19 10:05', 'Purchase Address': '80 4th St, San Francisco, CA 94016'}, {'Order ID': '209923', 'Product': 'ThinkPad Laptop', 'Quantity Ordered': '1', 'Price Each': '999.99', 'Order Date': '06/24/19 20:18', 'Purchase Address': '402 Jackson St, Los Angeles, CA 90001'}, {'Order ID': '209924', 'Product': '27in FHD Monitor', 'Quantity Ordered': '1', 'Price Each': '149.99', 'Order Date': '06/05/19 10:21', 'Purchase Address': '560 10th St, Seattle, WA 98101'}, {'Order ID': '209925', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/25/19 18:58', 'Purchase Address': '545 2nd St, San Francisco, CA 94016'}, {'Order ID': '209926', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/28/19 20:04', 'Purchase Address': '386 Lake St, Seattle, WA 98101'}, {'Order ID': '209927', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/28/19 00:07', 'Purchase Address': '29 Lincoln St, Los Angeles, CA 90001'}, {'Order ID': '209928', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/16/19 21:30', 'Purchase Address': '350 9th St, New York City, NY 10001'}, {'Order ID': '209929', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/28/19 10:56', 'Purchase Address': '612 Meadow St, Portland, OR 97035'}, {'Order ID': '209930', 'Product': '27in FHD Monitor', 'Quantity Ordered': '1', 'Price Each': '149.99', 'Order Date': '06/02/19 11:22', 'Purchase Address': '625 Ridge St, Los Angeles, CA 90001'}, {'Order ID': '209931', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/24/19 13:55', 'Purchase Address': '761 14th St, New York City, NY 10001'}, {'Order ID': '209932', 'Product': 'Flatscreen TV', 'Quantity Ordered': '1', 'Price Each': '300.0', 'Order Date': '06/12/19 14:36', 'Purchase Address': '858 8th St, Boston, MA 02215'}, {'Order ID': '209933', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/07/19 15:39', 'Purchase Address': '932 Lakeview St, San Francisco, CA 94016'}, {'Order ID': '209934', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/13/19 20:53', 'Purchase Address': '387 Dogwood St, Boston, MA 02215'}, {'Order ID': '209935', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/09/19 11:13', 'Purchase Address': '530 Cedar St, Boston, MA 02215'}, {'Order ID': '209936', 'Product': '34in Ultrawide Monitor', 'Quantity Ordered': '1', 'Price Each': '379.99', 'Order Date': '06/15/19 12:21', 'Purchase Address': '769 Dogwood St, Dallas, TX 75001'}, {'Order ID': '209937', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/29/19 18:01', 'Purchase Address': '675 Maple St, Dallas, TX 75001'}, {'Order ID': '209938', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/15/19 12:29', 'Purchase Address': '766 Meadow St, Seattle, WA 98101'}, {'Order ID': '209938', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/15/19 12:29', 'Purchase Address': '766 Meadow St, Seattle, WA 98101'}, {'Order ID': '209939', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/08/19 16:55', 'Purchase Address': '313 South St, San Francisco, CA 94016'}, {'Order ID': '209940', 'Product': '34in Ultrawide Monitor', 'Quantity Ordered': '1', 'Price E ...

# %%
def isnotnan(x):
    if isinstance(x['Order Date'], str):
        return True
    else:
        if math.isnan(x['Order Date']):
            return False
        return True
    
sales_data = list(filter(isnotnan, sales_data))

# me tomaba el nan como algo distinto de un str

# %%
sales_data[339:440]
# Out:
# [{'Order ID': '210251',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/03/19 21:02',
#   'Purchase Address': '110 Dogwood St, New York City, NY 10001'},
#  {'Order ID': '210252',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/15/19 18:53',
#   'Purchase Address': '10 Center St, Los Angeles, CA 90001'},
#  {'Order ID': '210253',
#   'Product': 'Google Phone',
#   'Quantity Ordered': '1',
#   'Price Each': '600',
#   'Order Date': '06/11/19 20:40',
#   'Purchase Address': '963 Lakeview St, Los Angeles, CA 90001'},
#  {'Order ID': '210253',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/11/19 20:40',
#   'Purchase Address': '963 Lakeview St, Los Angeles, CA 90001'},
#  {'Order ID': '210254',
#   'Product': 'ThinkPad Laptop',
#   'Quantity Ordered': '1',
#   'Price Each': '999.99',
#   'Order Date': '06/14/19 13:24',
#   'Purchase Address': '464 6th St, San Francisco, CA 94016'},
#  {'Order ID': '210255',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/09/19 21:56',
#   'Purchase Address': '274 5th St, New York City, NY 10001'},
#  {'Order ID': '210256',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '14.95',
#   'Order Date': '06/01/19 18:27',
#   'Purchase Address': '740 Adams St, San Francisco, CA 94016'},
#  {'Order ID': '210257',
#   'Product': '34in Ultrawide Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '379.99',
#   'Order Date': '06/16/19 13:33',
#   'Purchase Address': '302 Jefferson St, Boston, MA 02215'},
#  {'Order ID': '210258',
#   'Product': '34in Ultrawide Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '379.99',
#   'Order Date': '06/01/19 14:03',
#   'Purchase Address': '82 Cherry St, Austin, TX 73301'},
#  {'Order ID': '210259',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/05/19 15:08',
#   'Purchase Address': '832 Hill St, San Francisco, CA 94016'},
#  {'Order ID': '210260',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/22/19 15:59',
#   'Purchase Address': '916 9th St, San Francisco, CA 94016'},
#  {'Order ID': '210261',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '3.84',
#   'Order Date': '06/30/19 10:08',
#   'Purchase Address': '466 Ridge St, Atlanta, GA 30301'},
#  {'Order ID': '210262',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '2.99',
#   'Order Date': '06/22/19 19:50',
#   'Purchase Address': '912 Meadow St, San Francisco, CA 94016'},
#  {'Order ID': '210263',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/29/19 00:45',
#   'Purchase Address': '789 Johnson St, Los Angeles, CA 90001'},
#  {'Order ID': '210264',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '14.95',
#   'Order Date': '06/25/19 11:42',
#   'Purchase Address': '780 Lake St, New York City, NY 10001'},
#  {'Order ID': '210265',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/12/19 01:22',
#   'Purchase Address': '620 Highland St, Dallas, TX 75001'},
#  {'Order ID': '210266',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/14/19 11:43',
#   'Purchase Address': '282 Elm St, Los Angeles, CA 90001'},
#  {'Order ID': '210267',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/24/19 10:23',
#   'Purchase Address': '946 Johnson St, Los Angeles, CA 90001'},
#  {'Order ID': '210268',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/04/19 18:59',
#   'Purchase Address': '498 Park St, Dallas, TX 75001'},
#  {'Order ID': '210269',
#   'Product': 'Bose SoundSport Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '99.99',
#   'Order Date': '06/15/19 21:31',
#   'Purchase Address': '212 Wilson St, Los Angeles, CA 90001'},
#  {'Order ID': '210270',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '14.95',
#   'Order Date': '06/06/19 12:34',
#   'Purchase Address': '175 Sunset St, Los Angeles, CA 90001'},
#  {'Order ID': '210271',
#   'Product': 'Vareebadd Phone',
#   'Quantity Ordered': '1',
#   'Price Each': '400',
#   'Order Date': '06/15/19 16:00',
#   'Purchase Address': '318 Church St, San Francisco, CA 94016'},
#  {'Order ID': '210271',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/15/19 16:00',
#   'Purchase Address': '318 Church St, San Francisco, CA 94016'},
#  {'Order ID': '210272',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/19/19 05:46',
#   'Purchase Address': '726 Meadow St, San Francisco, CA 94016'},
#  {'Order ID': '210273',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '3.84',
#   'Order Date': '06/19/19 13:42',
#   'Purchase Address': '391 Highland St, San Francisco, CA 94016'},
#  {'Order ID': '210274',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/22/19 21:48',
#   'Purchase Address': '436 West St, Atlanta, GA 30301'},
#  {'Order ID': '210274',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/22/19 21:48',
#   'Purchase Address': '436 West St, Atlanta, GA 30301'},
#  {'Order ID': '210275',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/21/19 09:15',
#   'Purchase Address': '63 Forest St, Dallas, TX 75001'},
#  {'Order ID': '210276',
#   'Product': 'ThinkPad Laptop',
#   'Quantity Ordered': '1',
#   'Price Each': '999.99',
#   'Order Date': '06/21/19 20:16',
#   'Purchase Address': '719 Cedar St, San Francisco, CA 94016'},
#  {'Order ID': '210277',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '14.95',
#   'Order Date': '06/16/19 14:39',
#   'Purchase Address': '294 Johnson St, Los Angeles, CA 90001'},
#  {'Order ID': '210278',
#   'Product': 'Flatscreen TV',
#   'Quantity Ordered': '1',
#   'Price Each': '300',
#   'Order Date': '06/20/19 11:22',
#   'Purchase Address': '897 Walnut St, Austin, TX 73301'},
#  {'Order ID': '210279',
#   'Product': 'Flatscreen TV',
#   'Quantity Ordered': '1',
#   'Price Each': '300',
#   'Order Date': '06/14/19 09:02',
#   'Purchase Address': '809 Spruce St, San Francisco, CA 94016'},
#  {'Order ID': '210280',
#   'Product': 'Bose SoundSport Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '99.99',
#   'Order Date': '06/30/19 21:08',
#   'Purchase Address': '617 8th St, New York City, NY 10001'},
#  {'Order ID': '210281',
#   'Product': '34in Ultrawide Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '379.99',
#   'Order Date': '06/02/19 20:09',
#   'Purchase Address': '230 9th St, Dallas, TX 75001'},
#  {'Order ID': '210282',
#   'Product': 'ThinkPad Laptop',
#   'Quantity Ordered': '1',
#   'Price Each': '999.99',
#   'Order Date': '06/02/19 19:35',
#   'Purchase Address': '572 Jefferson St, San Francisco, CA 94016'},
#  {'Order ID': '210283',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/24/19 21:15',
#   'Purchase Address': '774 West St, San Francisco, CA 94016'},
#  {'Order ID': '210284',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/16/19 21:00',
#   'Purchase Address': '154 Johnson St, Boston, MA 02215'},
#  {'Order ID': '210285',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '3',
#   'Price Each': '2.99',
#   'Order Date': '06/14/19 18:49',
#   'Purchase Address': '333 Elm St, Boston, MA 02215'},
#  {'Order ID': '210285',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/14/19 18:49',
#   'Purchase Address': '333 Elm St, Boston, MA 02215'},
#  {'Order ID': '210286',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/30/19 17:11',
#   'Purchase Address': '300 Elm St, Los Angeles, CA 90001'},
#  {'Order ID': '210287',
#   'Product': 'Bose SoundSport Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '99.99',
#   'Order Date': '06/17/19 07:28',
#   'Purchase Address': '244 11th St, San Francisco, CA 94016'},
#  {'Order ID': '210288',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '2.99',
#   'Order Date': '06/11/19 06:44',
#   'Purchase Address': '439 Johnson St, San Francisco, CA 94016'},
#  {'Order ID': '210289',
#   'Product': '27in 4K Gaming Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '389.99',
#   'Order Date': '06/22/19 23:18',
#   'Purchase Address': '634 Church St, Los Angeles, CA 90001'},
#  {'Order ID': '210290',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/15/19 10:47',
#   'Purchase Address': '322 Main St, San Francisco, CA 94016'},
#  {'Order ID': '210291',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '3',
#   'Price Each': '3.84',
#   'Order Date': '06/29/19 10:09',
#   'Purchase Address': '706 Sunset St, New York City, NY 10001'},
#  {'Order ID': '210292',
#   'Product': 'Macbook Pro Laptop',
#   'Quantity Ordered': '2',
#   'Price Each': '1700',
#   'Order Date': '06/08/19 09:00',
#   'Purchase Address': '953 Ridge St, San Francisco, CA 94016'},
#  {'Order ID': '210293',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '3.84',
#   'Order Date': '06/17/19 13:47',
#   'Purchase Address': '934 North St, Seattle, WA 98101'},
#  {'Order ID': '210294',
#   'Product': 'iPhone',
#   'Quantity Ordered': '1',
#   'Price Each': '700',
#   'Order Date': '06/06/19 15:00',
#   'Purchase Address': '771 Chestnut St, Portland, OR 97035'},
#  {'Order ID': '210295',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/17/19 18:35',
#   'Purchase Address': '944 Meadow St, Los Angeles, CA 90001'},
#  {'Order ID': '210296',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/19/19 13:41',
#   'Purchase Address': '74 Lincoln St, Los Angeles, CA 90001'},
#  {'Order ID': '210297',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '2.99',
#   'Order Date': '06/08/19 19:59',
#   'Purchase Address': '336 4th St, Los Angeles, CA 90001'},
#  {'Order ID': '210298',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/11/19 20:42',
#   'Purchase Address': '429 10th St, Dallas, TX 75001'},
#  {'Order ID': '210299',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/06/19 14:26',
#   'Purchase Address': '454 9th St, San Francisco, CA 94016'},
#  {'Order ID': '210300',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/12/19 10:12',
#   'Purchase Address': '145 Hill St, San Francisco, CA 94016'},
#  {'Order ID': '210301',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/10/19 16:20',
#   'Purchase Address': '361 Meadow St, Los Angeles, CA 90001'},
#  {'Order ID': '210302',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/24/19 15:52',
#   'Purchase Address': '800 8th St, Austin, TX 73301'},
#  {'Order ID': '210303',
#   'Product': 'Vareebadd Phone',
#   'Quantity Ordered': '1',
#   'Price Each': '400',
#   'Order Date': '06/02/19 19:38',
#   'Purchase Address': '578 7th St, Los Angeles, CA 90001'},
#  {'Order ID': '210304',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/16/19 19:39',
#   'Purchase Address': '357 4th St, San Francisco, CA 94016'},
#  {'Order ID': '210305',
#   'Product': 'Macbook Pro Laptop',
#   'Quantity Ordered': '1',
#   'Price Each': '1700',
#   'Order Date': '06/06/19 06:49',
#   'Purchase Address': '51 Chestnut St, Los Angeles, CA 90001'},
#  {'Order ID': '210306',
#   'Product': '20in Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '109.99',
#   'Order Date': '06/19/19 19:09',
#   'Purchase Address': '785 Forest St, New York City, NY 10001'},
#  {'Order ID': '210307',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/03/19 11:54',
#   'Purchase Address': '866 4th St, Los Angeles, CA 90001'},
#  {'Order ID': '210308',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '2.99',
#   'Order Date': '06/19/19 17:35',
#   'Purchase Address': '433 Lake St, Los Angeles, CA 90001'},
#  {'Order ID': '210309',
#   'Product': '34in Ultrawide Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '379.99',
#   'Order Date': '06/26/19 10:58',
#   'Purchase Address': '676 Cedar St, Austin, TX 73301'},
#  {'Order ID': '210310',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/12/19 10:27',
#   'Purchase Address': '268 Washington St, New York City, NY 10001'},
#  {'Order ID': '210310',
#   'Product': 'Flatscreen TV',
#   'Quantity Ordered': '1',
#   'Price Each': '300',
#   'Order Date': '06/12/19 10:27',
#   'Purchase Address': '268 Washington St, New York City, NY 10001'},
#  {'Order ID': '210311',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/25/19 20:48',
#   'Purchase Address': '610 Main St, Los Angeles, CA 90001'},
#  {'Order ID': '210312',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/19/19 10:42',
#   'Purchase Address': '788 1st St, Portland, OR 97035'},
#  {'Order ID': '210313',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/09/19 20:04',
#   'Purchase Address': '235 1st St, San Francisco, CA 94016'},
#  {'Order ID': '210314',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/06/19 15:31',
#   'Purchase Address': '345 Spruce St, Los Angeles, CA 90001'},
#  {'Order ID': '210315',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '14.95',
#   'Order Date': '06/22/19 18:13',
#   'Purchase Address': '248 River St, Atlanta, GA 30301'},
#  {'Order ID': '210316',
#   'Product': 'Flatscreen TV',
#   'Quantity Ordered': '1',
#   'Price Each': '300',
#   'Order Date': '06/14/19 00:35',
#   'Purchase Address': '676 River St, Dallas, TX 75001'},
#  {'Order ID': '210317',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/25/19 10:48',
#   'Purchase Address': '18 Dogwood St, San Francisco, CA 94016'},
#  {'Order ID': '210318',
#   'Product': '34in Ultrawide Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '379.99',
#   'Order Date': '06/22/19 23:07',
#   'Purchase Address': '344 Highland St, Los Angeles, CA 90001'},
#  {'Order ID': '210319',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/20/19 18:18',
#   'Purchase Address': '228 Forest St, Seattle, WA 98101'},
#  {'Order ID': '210320',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/22/19 10:23',
#   'Purchase Address': '465 Madison St, San Francisco, CA 94016'},
#  {'Order ID': '210320',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '2.99',
#   'Order Date': '06/22/19 10:23',
#   'Purchase Address': '465 Madison St, San Francisco, CA 94016'},
#  {'Order ID': '210321',
#   'Product': 'Google Phone',
#   'Quantity Ordered': '1',
#   'Price Each': '600',
#   'Order Date': '06/16/19 10:34',
#   'Purchase Address': '702 1st St, Atlanta, GA 30301'},
#  {'Order ID': '210322',
#   'Product': 'Bose SoundSport Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '99.99',
#   'Order Date': '06/06/19 19:01',
#   'Purchase Address': '855 2nd St, Los Angeles, CA 90001'},
#  {'Order ID': '210323',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '3.84',
#   'Order Date': '06/06/19 15:46',
#   'Purchase Address': '500 12th St, Portland, ME 04101'},
#  {'Order ID': '210324',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '2',
#   'Price Each': '2.99',
#   'Order Date': '06/23/19 14:50',
#   'Purchase Address': '436 Walnut St, San Francisco, CA 94016'},
#  {'Order ID': '210325',
#   'Product': 'Flatscreen TV',
#   'Quantity Ordered': '1',
#   'Price Each': '300',
#   'Order Date': '06/21/19 08:26',
#   'Purchase Address': '190 West St, Seattle, WA 98101'},
#  {'Order ID': '210326',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/16/19 12:23',
#   'Purchase Address': '596 Park St, Atlanta, GA 30301'},
#  {'Order ID': '210327',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/29/19 19:02',
#   'Purchase Address': '64 1st St, Los Angeles, CA 90001'},
#  {'Order ID': '210328',
#   'Product': 'Macbook Pro Laptop',
#   'Quantity Ordered': '1',
#   'Price Each': '1700',
#   'Order Date': '06/29/19 11:25',
#   'Purchase Address': '586 Highland St, Austin, TX 73301'},
#  {'Order ID': '210329',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '2.99',
#   'Order Date': '06/03/19 12:14',
#   'Purchase Address': '261 West St, Atlanta, GA 30301'},
#  {'Order ID': '210330',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/16/19 22:14',
#   'Purchase Address': '772 Spruce St, Boston, MA 02215'},
#  {'Order ID': '210331',
#   'Product': 'iPhone',
#   'Quantity Ordered': '1',
#   'Price Each': '700',
#   'Order Date': '06/20/19 20:23',
#   'Purchase Address': '834 Ridge St, New York City, NY 10001'},
#  {'Order ID': '210332',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/01/19 08:25',
#   'Purchase Address': '285 12th St, Los Angeles, CA 90001'},
#  {'Order ID': '210333',
#   'Product': 'Bose SoundSport Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '99.99',
#   'Order Date': '06/17/19 12:52',
#   'Purchase Address': '924 Jefferson St, Portland, OR 97035'},
#  {'Order ID': '210334',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '14.95',
#   'Order Date': '06/20/19 20:10',
#   'Purchase Address': '895 Washington St, Boston, MA 02215'},
#  {'Order ID': '210335',
#   'Product': '27in FHD Monitor',
#   'Quantity Ordered': '1',
#   'Price Each': '149.99',
#   'Order Date': '06/15/19 19:33',
#   'Purchase Address': '403 Cedar St, San Francisco, CA 94016'},
#  {'Order ID': '210336',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/17/19 14:43',
#   'Purchase Address': '159 Washington St, Seattle, WA 98101'},
#  {'Order ID': '210337',
#   'Product': 'Lightning Charging Cable',
#   'Quantity Ordered': '2',
#   'Price Each': '14.95',
#   'Order Date': '06/05/19 18:37',
#   'Purchase Address': '922 Wilson St, Austin, TX 73301'},
#  {'Order ID': '210338',
#   'Product': 'AAA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '2.99',
#   'Order Date': '06/13/19 13:07',
#   'Purchase Address': '595 Jackson St, Boston, MA 02215'},
#  {'Order ID': '210339',
#   'Product': 'Bose SoundSport Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '99.99',
#   'Order Date': '06/26/19 08:08',
#   'Purchase Address': '721 2nd St, San Francisco, CA 94016'},
#  {'Order ID': '210340',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/15/19 20:27',
#   'Purchase Address': '34 10th St, Boston, MA 02215'},
#  {'Order ID': '210341',
#   'Product': 'USB-C Charging Cable',
#   'Quantity Ordered': '1',
#   'Price Each': '11.95',
#   'Order Date': '06/15/19 09:25',
#   'Purchase Address': '766 Wilson St, Atlanta, GA 30301'},
#  {'Order ID': '210342',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/14/19 12:17',
#   'Purchase Address': '846 Hill St, San Francisco, CA 94016'},
#  {'Order ID': '210343',
#   'Product': 'Wired Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '11.99',
#   'Order Date': '06/03/19 12:04',
#   'Purchase Address': '879 Hickory St, San Francisco, CA 94016'},
#  {'Order ID': '210344',
#   'Product': 'Apple Airpods Headphones',
#   'Quantity Ordered': '1',
#   'Price Each': '150',
#   'Order Date': '06/24/19 15:59',
#   'Purchase Address': '289 Cedar St, San Francisco, CA 94016'},
#  {'Order ID': '210345',
#   'Product': 'AA Batteries (4-pack)',
#   'Quantity Ordered': '1',
#   'Price Each': '3.84',
#   'Order Date': '06/01/19 09:44',
#   'Purchase Address': '73 Ridge St, Austin, TX 73301'}]

# %% [markdown]
# Responder los siguientes interrogantes de interés, para lo que se requiere:
#
# * Inspeccionar los datos
# * Formatearlos adecuadamente
# * Elegir y confeccionar nuevas estructuras de datos

# %% [markdown]
# **1)** ¿Cuál es el mes que reporta **la mayor cantidad de productos**?
#
# *Se espera*: `El mes de mayor venta es: {Enero/Febrero/Marzo/Abril...}` *(nótese que se debe printear el nombre del mes)*

# %%
print(f'El mes de mayor venta es: {month}')

# %%
dates_dict = {}

for k in sales_data:
    try:
        if not k['Order Date'][0:2] in dates_dict and k['Order Date'][0:2].isdigit(): #solo quiero quedarme con los números, me aparecia un 'or'.
            dates_dict[k['Order Date'][0:2]] = 0
        if k['Order Date'][0:2].isdigit():
            dates_dict[k['Order Date'][0:2]] =  dates_dict[k['Order Date'][0:2]] + 1
    except: 
        print('a')
        
print(dates_dict)
# Out:
# {'06': 13554, '07': 14293, '12': 24984, '01': 9709, '02': 11975, '03': 15153, '09': 11621, '10': 20282, '04': 18279, '05': 16566, '08': 11961, '11': 17573}

# %%
max_value = max(list(dates_dict.values()))

for k,v in dates_dict.items():
    if v == max_value:
        month = k
month = 'Diciembre'       
print(f'el mes de mayor venta es: {month}')
# Out:
# el mes de mayor venta es: Diciembre

# %% [markdown]
# **2)** ¿Qué ganancia reporta dicho mes?
# *Se espera*: `En el mes de {Enero/Febrero/Marzo/Abril...} se reporta una ganancia total de USD{xxxx.xx}` *(nótese que el monto debe incluir DOS decimales)*

# %%
gain_dict = []

for k in sales_data:
    if k['Order Date'][0:2] == '12':
        gain_dict.append(k['Price Each'])

# %%
new_list = []
for item in gain_dict:
    new_list.append(float(item))
    
sum_month = sum(new_list)
print(f'En el mes de {month} se reporta una ganancia total de USD {round(sum_month, 2)}')
# Out:
# En el mes de Diciembre se reporta una ganancia total de USD 4588415.41

# %% [markdown]
# **3)** ¿Qué porcentaje del total de las ventas representa?
# *Se espera*: `Las ventas en el mes de {Enero/Febrero/Marzo/Abril...} representan un xx.xx% del total de las ventas` *(nótese que el monto debe incluir DOS decimales)*

# %%
ventas = []
new_percentage = []

for k in sales_data:
    if not k in ventas:
        ventas.append(k['Price Each'])
print(ventas)   # obtuve una lista con todas las ventas
# Out:
# ['11.95', '1700.0', '999.99', '149.99', '99.99', '150.0', '14.95', '150.0', '11.99', '149.99', '150.0', '300.0', '3.84', '2.99', '2.99', '379.99', '3.84', '700.0', '11.99', '600.0', '379.99', '11.99', '389.99', '2.99', '149.99', '3.84', '600.0', '150.0', '1700.0', '600.0', '11.95', '11.99', '389.99', '109.99', '600.0', '700.0', '3.84', '3.84', '3.84', '11.99', '11.95', '11.95', '3.84', '700.0', '14.95', '11.95', '14.95', '11.95', '109.99', '14.95', '3.84', '150.0', '150.0', '2.99', '3.84', '11.99', '99.99', '11.95', '3.84', '150.0', '3.84', '14.95', '11.95', '99.99', '700.0', '389.99', '1700.0', '11.95', '150.0', '109.99', '2.99', '11.99', '700.0', '600.0', '2.99', '150.0', '11.95', '14.95', '389.99', '600.0', '3.84', '99.99', '99.99', '700.0', '3.84', '2.99', '99.99', '2.99', '2.99', '14.95', '700.0', '149.99', '99.99', '11.95', '3.84', '379.99', '3.84', '11.99', '11.99', '3.84', '2.99', '14.95', '14.95', '150.0', '2.99', '14.95', '3.84', '2.99', '109.99', '99.99', '1700.0', '149.99', '99.99', '1700.0', '2.99', '3.84', '3.84', '389.99', '149.99', '3.84', '2.99', '999.99', '2.99', '3.84', '149.99', '300.0', '150.0', '150.0', '99.99', '150.0', '379.99', '11.99', '999.99', '99.99', '700.0', '11.95', '14.95', '14.95', '150.0', '1700.0', '2.99', '14.95', '149.99', '11.95', '300.0', '2.99', '14.95', '14.95', '149.99', '14.95', '700.0', '11.99', '3.84', '600.0', '2.99', '14.95', '3.84', '99.99', 'Price Each', '3.84', '11.95', '3.84', '11.99', '999.99', '600.0', '2.99', '99.99', '11.95', '14.95', '999.99', '149.99', '379.99', '14.95', '11.99', '11.95', '2.99', '1700', '11.95', '150', '2.99', '2.99', '149.99', '14.95', '2.99', '14.95', '150', '400', '11.99', '600', '99.99', '3.84', '11.99', '14.95', '149.99', '14.95', '150', '14.95', '11.95', '11.95', '11.99', '150', '99.99', '99.99', '99.99', '11.99', '3.84', '11.99', '3.84', '2.99', '11.99', '150', '109.99', '3.84', '14.95', '11.95', '2.99', '3.84', '150', '3.84', '3.84', '11.99', '11.99', '3.84', '389.99', '3.84', '3.84', '99.99', '300', '99.99', '389.99', '3.84', '109.99', '3.84', '99.99', '109.99', '11.99', '11.95', '149.99', '11.95', '2.99', '14.95', '700', '2.99', '11.95', '3.84', '389.99', '11.99', '1700', '150', '1700', '11.95', '2.99', '149.99', '99.99', '150', '11.95', '3.84', '400', '600', '11.95', '109.99', '149.99', '2.99', '600', '11.99', '379.99', '600', '149.99', '700', '3.84', '2.99', '11.99', '700', '11.95', '14.95', '2.99', '700', '379.99', '300', '150', '379.99', '11.95', '150', '2.99', '600.0', '389.99', '600', '379.99', '99.99', '99.99', '99.99', '150', '300', '11.99', '600', '11.95', '11.95', '999.99', '600.0', '3.84', '3.84', '99.99', '149.99', '2.99', '2.99', '109.99', '14.95', '11.95', '2.99', '109.99', '379.99', '2.99', '150', '11.95', '300', '11.95', '3.84', '14.95', '11.95', '11.99', '11.99', '3.84', '14.95', '379.99', '11.99', '11.99', '2.99', '389.99', '2.99', '150', '11.95', '3.84', '14.95', '2.99', '14.95', '14.95', '3.84', '600', '11.99', '11.95', '3.84', '600', '11.95', '999.99', '11.95', '14.95', '379.99', '379.99', '11.99', '3.84', '3.84', '2.99', '11.95', '14.95', '149.99', '149.99', '11.95', '3.84', '99.99', '14.95', '400', '11.95', '11.95', '3.84', '149.99', '150', '150', '999.99', '14.95', '300', '300', '99.99', '379.99', '999.99', '11.99', '11.95', '2.99', '150', '11.95', '99.99', '2.99', '389.99', '150', '3.84', '1700', '3.84', '700', '150', '149.99', '2.99', '11.95', '150', '149.99', '149.99', '150', '400', '150', '1700', '109.99', '149.99', '2.99', '379.99', '11.95', '300', '150', '150', '3.84', '11.99', '14.95', '300', '149.99', '379.99', '11.95', '150', '2.99', '600', '99.99', '3.84', '2.99', '300', '3.84', '11.95', '1700', '2.99', '150', '700', '11.99', '99.99', '14.95', '149.99', '11.99', '14.95', '2.99', '99.99', '3.84', '11.95', '11.99', '11.99', '150', '3.84', '11.99', '11.99', '600', '11.95', '1700', '2.99', '99.99', '11.95', '11.95', '11.95', '999.99', '11.95', '150', '999.99', '3.84', '700', '14.95', '999.99', '11.95', '2.99', '3 ...

# %%
new_value = []
for item in ventas:
    try:   
        new_value.append(float(item))
    
    except ValueError:
            continue
        
sum_total = sum(new_value) 
print(sum_total) # convertí la lista con precios de ventas a float para sumar y obtener el total de ventas
# Out:
# 34289130.67992488

# %%
total = (sum_month / sum_total) * 100
print(f'Las ventas en el mes de {month} representan un {round(total, 2)}% del total de las ventas')
# Out:
# Las ventas en el mes de Diciembre representan un 13.38% del total de las ventas

# %% [markdown]
# **4)** ¿Qué ciudad reportó la mayor cantidad de ventas?
# *Se espera*: `La ciudad con mayor cantidad de ventas es {Dallas/Los Angeles/Boston...} reporta la mayor cantidad de ventas` *(nótese que se debe especificar la ciudad y no la dirección completa)*

# %%
value_price = []
key_city = []
for k in sales:
    try:
        if not k['Purchase Address'].split(',')[1] in key_city:
            key_city.append(k['Purchase Address'].split(',')[1])
   
    
        for k in sales_data:
            if not k['Price Each'] in value_price:
                value_price.append(k['Price Each']) 
    
    except IndexError:
            continue
        
dict_from_list = {k: v for k, v in zip(key_city, value_price)}
print(dict_from_list)
# Out:
# {' Portland': '11.95', ' San Francisco': '1700.0', ' Los Angeles': '999.99', ' Seattle': '149.99', ' New York City': '99.99', ' Boston': '150.0', ' Dallas': '14.95', ' Atlanta': '11.99', ' Austin': '300.0'}

# %% [markdown]
# **5)** ¿Qué porcentaje del total de las ventas representa?
# *Se espera*: `Las ventas en {Dallas/Los Angeles/Boston...} representan un xx.xx% del total` *(nótese que se debe especificar la ciudad y no la dirección completa)*

# %% [markdown]
# **6)** ¿En qué horas del día se deberían publicar anuncios promocionales para maximizar las ventas?
# *Se espera*: `Las horas del día en las que más ventas se registran son: {xx}hs y {yy}hs` *(nótese que se requieren horas del día, como "10hs" o "20hs")*

# %%
rango_de_hora = range(0,24)

for k in sales:
    if k['Order Date'][0:2]:
        print(k)
# Out:
# {'Order ID': '209921', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/23/19 19:34', 'Purchase Address': '950 Walnut St, Portland, ME 04101'}
# {'Order ID': '209922', 'Product': 'Macbook Pro Laptop', 'Quantity Ordered': '1', 'Price Each': '1700.0', 'Order Date': '06/30/19 10:05', 'Purchase Address': '80 4th St, San Francisco, CA 94016'}
# {'Order ID': '209923', 'Product': 'ThinkPad Laptop', 'Quantity Ordered': '1', 'Price Each': '999.99', 'Order Date': '06/24/19 20:18', 'Purchase Address': '402 Jackson St, Los Angeles, CA 90001'}
# {'Order ID': '209924', 'Product': '27in FHD Monitor', 'Quantity Ordered': '1', 'Price Each': '149.99', 'Order Date': '06/05/19 10:21', 'Purchase Address': '560 10th St, Seattle, WA 98101'}
# {'Order ID': '209925', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/25/19 18:58', 'Purchase Address': '545 2nd St, San Francisco, CA 94016'}
# {'Order ID': '209926', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/28/19 20:04', 'Purchase Address': '386 Lake St, Seattle, WA 98101'}
# {'Order ID': '209927', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/28/19 00:07', 'Purchase Address': '29 Lincoln St, Los Angeles, CA 90001'}
# {'Order ID': '209928', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/16/19 21:30', 'Purchase Address': '350 9th St, New York City, NY 10001'}
# {'Order ID': '209929', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/28/19 10:56', 'Purchase Address': '612 Meadow St, Portland, OR 97035'}
# {'Order ID': '209930', 'Product': '27in FHD Monitor', 'Quantity Ordered': '1', 'Price Each': '149.99', 'Order Date': '06/02/19 11:22', 'Purchase Address': '625 Ridge St, Los Angeles, CA 90001'}
# {'Order ID': '209931', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/24/19 13:55', 'Purchase Address': '761 14th St, New York City, NY 10001'}
# {'Order ID': '209932', 'Product': 'Flatscreen TV', 'Quantity Ordered': '1', 'Price Each': '300.0', 'Order Date': '06/12/19 14:36', 'Purchase Address': '858 8th St, Boston, MA 02215'}
# {'Order ID': '209933', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/07/19 15:39', 'Purchase Address': '932 Lakeview St, San Francisco, CA 94016'}
# {'Order ID': '209934', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/13/19 20:53', 'Purchase Address': '387 Dogwood St, Boston, MA 02215'}
# {'Order ID': '209935', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/09/19 11:13', 'Purchase Address': '530 Cedar St, Boston, MA 02215'}
# {'Order ID': '209936', 'Product': '34in Ultrawide Monitor', 'Quantity Ordered': '1', 'Price Each': '379.99', 'Order Date': '06/15/19 12:21', 'Purchase Address': '769 Dogwood St, Dallas, TX 75001'}
# {'Order ID': '209937', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/29/19 18:01', 'Purchase Address': '675 Maple St, Dallas, TX 75001'}
# {'Order ID': '209938', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/15/19 12:29', 'Purchase Address': '766 Meadow St, Seattle, WA 98101'}
# {'Order ID': '209938', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/15/19 12:29', 'Purchase Address': '766 Meadow St, Seattle, WA 98101'}
# {'Order ID': '209939', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/08/19 16:55', 'Purchase Address': '313 South St, San Francisco, CA 94016'}
# {'Order ID': '209940', 'Product': '34in Ultrawide Monitor', 'Quantity Ordered': '1', 'Price Each': '379.99', 'Order Date': '06/26/19 15:24', 'Purchase Address': '990 South St, Atlanta, GA 30301'}
# {'Order ID': '209941', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/27/19 11:18', 'Purchase Address': '486 13th St, Boston, MA 02215'}
# {'Order ID': '209942', 'Product': '27in 4K Gaming Monitor', 'Quantity Ordered': '1', 'Price Each': '389.99', 'Order Date': '06/19/19 13:52', 'Purchase Address': '874 Wilson St, Austin, TX 73301'}
# {'Order ID': '209943', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '3', 'Price Each': '2.99', 'Order Date': '06/23/19 16:19', 'Purchase Address': '158 Willow St, Los Angeles, CA 90001'}
# {'Order ID': '209944', 'Product': '27in FHD Monitor', 'Quantity Ordered': '1', 'Price Each': '149.99', 'Order Date': '06/02/19 19:10', 'Purchase Address': '916 Lake St, Austin, TX 73301'}
# {'Order ID': '209945', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/28/19 08:53', 'Purchase Address': '211 12th St, San Francisco, CA 94016'}
# {'Order ID': '209946', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/28/19 22:13', 'Purchase Address': '66 Cherry St, San Francisco, CA 94016'}
# {'Order ID': '209947', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/06/19 22:41', 'Purchase Address': '7 Lakeview St, San Francisco, CA 94016'}
# {'Order ID': '209948', 'Product': 'Macbook Pro Laptop', 'Quantity Ordered': '1', 'Price Each': '1700.0', 'Order Date': '06/09/19 01:48', 'Purchase Address': '101 Spruce St, Atlanta, GA 30301'}
# {'Order ID': '209949', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/23/19 07:45', 'Purchase Address': '637 12th St, San Francisco, CA 94016'}
# {'Order ID': '209949', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/23/19 07:45', 'Purchase Address': '637 12th St, San Francisco, CA 94016'}
# {'Order ID': '209950', 'Product': 'Wired Headphones', 'Quantity Ordered': '2', 'Price Each': '11.99', 'Order Date': '06/01/19 18:03', 'Purchase Address': '689 Walnut St, Los Angeles, CA 90001'}
# {'Order ID': '209951', 'Product': '27in 4K Gaming Monitor', 'Quantity Ordered': '1', 'Price Each': '389.99', 'Order Date': '06/30/19 13:04', 'Purchase Address': '998 Johnson St, New York City, NY 10001'}
# {'Order ID': '209952', 'Product': '20in Monitor', 'Quantity Ordered': '1', 'Price Each': '109.99', 'Order Date': '06/26/19 17:48', 'Purchase Address': '314 Willow St, Dallas, TX 75001'}
# {'Order ID': '209953', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/16/19 16:59', 'Purchase Address': '753 6th St, Dallas, TX 75001'}
# {'Order ID': '209954', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/16/19 07:21', 'Purchase Address': '599 2nd St, San Francisco, CA 94016'}
# {'Order ID': '209955', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/15/19 21:25', 'Purchase Address': '549 2nd St, Atlanta, GA 30301'}
# {'Order ID': '209956', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '2', 'Price Each': '3.84', 'Order Date': '06/26/19 15:23', 'Purchase Address': '910 Jackson St, Seattle, WA 98101'}
# {'Order ID': '209957', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/13/19 12:23', 'Purchase Address': '545 Dogwood St, Los Angeles, CA 90001'}
# {'Order ID': '209958', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/06/19 12:09', 'Purchase Address': '326 Hickory St, Los Angeles, CA 90001'}
# {'Order ID': '209959', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/01/19 15:48', 'Purchase Address': '88 River St, Atlanta, GA 30301'}
# {'Order ID': '209960', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/22/19 11:53', 'Purchase Address': '333 Sunset St, Dallas, TX 75001'}
# {'Order ID': '209960', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/22/19 11:53', 'Purchase Address': '333 Sunset St, Dallas, TX 75001'}
# {'Order ID': '209961', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/01/19 23:00', 'Purchase Address': '482 South St, Austin, TX 73301'}
# {'Order ID': '209961', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/01/19 23:00', 'Purchase Address': '482 South St, Austin, TX 73301'}
# {'Order ID': '209962', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/23/19 10:58', 'Purchase Address': '441 Cherry St, New York City, NY 10001'}
# {'Order ID': '209963', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/13/19 18:58', 'Purchase Address': '551 Hill St, Boston, MA 02215'}
# {'Order ID': '209964', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '2', 'Price Each': '11.95', 'Order Date': '06/11/19 14:30', 'Purchase Address': '822 8th St, Los Angeles, CA 90001'}
# {'Order ID': '209965', 'Product': '20in Monitor', 'Quantity Ordered': '1', 'Price Each': '109.99', 'Order Date': '06/24/19 14:00', 'Purchase Address': '910 North St, San Francisco, CA 94016'}
# {'Order ID': '209966', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/20/19 09:46', 'Purchase Address': '743 Adams St, New York City, NY 10001'}
# {'Order ID': '209967', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '2', 'Price Each': '3.84', 'Order Date': '06/21/19 21:18', 'Purchase Address': '584 Chestnut St, San Francisco, CA 94016'}
# {'Order ID': '209968', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/23/19 13:06', 'Purchase Address': '120 Church St, Dallas, TX 75001'}
# {'Order ID': '209969', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/21/19 15:55', 'Purchase Address': '133 Sunset St, Los Angeles, CA 90001'}
# {'Order ID': '209970', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/08/19 20:58', 'Purchase Address': '181 Meadow St, Seattle, WA 98101'}
# {'Order ID': '209971', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/22/19 15:11', 'Purchase Address': '440 Maple St, Dallas, TX 75001'}
# {'Order ID': '209972', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/14/19 17:09', 'Purchase Address': '690 11th St, New York City, NY 10001'}
# {'Order ID': '209973', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/06/19 12:20', 'Purchase Address': '658 Highland St, Austin, TX 73301'}
# {'Order ID': '209974', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/11/19 10:06', 'Purchase Address': '555 9th St, New York City, NY 10001'}
# {'Order ID': '209975', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '3', 'Price Each': '3.84', 'Order Date': '06/05/19 21:25', 'Purchase Address': '152 Johnson St, New York City, NY 10001'}
# {'Order ID': '209976', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/26/19 11:52', 'Purchase Address': '966 Washington St, Atlanta, GA 30301'}
# {'Order ID': '209977', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/01/19 06:28', 'Purchase Address': '96 14th St, Los Angeles, CA 90001'}
# {'Order ID': '209978', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/05/19 13:50', 'Purchase Address': '57 1st St, Los Angeles, CA 90001'}
# {'Order ID': '209979', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/24/19 09:42', 'Purchase Address': '979 2nd St, San Francisco, CA 94016'}
# {'Order ID': '209980', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/28/19 20:28', 'Purchase Address': '875 Forest St, New York City, NY 10001'}
# {'Order ID': '209981', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/05/19 19:25', 'Purchase Address': '898 14th St, Los Angeles, CA 90001'}
# {'Order ID': '209982', 'Product': '27in 4K Gaming Monitor', 'Quantity Ordered': '1', 'Price Each': '389.99', 'Order Date': '06/17/19 19:31', 'Purchase Address': '315 Forest St, New York City, NY 10001'}
# {'Order ID': '209983', 'Product': 'Macbook Pro Laptop', 'Quantity Ordered': '1', 'Price Each': '1700.0', 'Order Date': '06/22/19 16:25', 'Purchase Address': '702 Center St, Seattle, WA 98101'}
# {'Order ID': '209984', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/03/19 06:50', 'Purchase Address': '36 7th St, Seattle, WA 98101'}
# {'Order ID': '209985', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/05/19 22:18', 'Purchase Address': '54 12th St, Portland, OR 97035'}
# {'Order ID': '209986', 'Product': '20in Monitor', 'Quantity Ordered': '1', 'Price Each': '109.99', 'Order Date': '06/23/19 16:49', 'Purchase Address': '11 Wilson St, New York City, NY 10001'}
# {'Order ID': '209987', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '3', 'Price Each': '2.99', 'Order Date': '06/03/19 03:22', 'Purchase Address': '76 River St, Los Angeles, CA 90001'}
# {'Order ID': '209988', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/27/19 18:04', 'Purchase Address': '403 Main St, San Francisco, CA 94016'}
# {'Order ID': '209989', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/19/19 23:34', 'Purchase Address': '285 8th St, Los Angeles, CA 90001'}
# {'Order ID': '209990', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/16/19 20:31', 'Purchase Address': '557 Wilson St, Austin, TX 73301'}
# {'Order ID': '209991', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/02/19 19:00', 'Purchase Address': '835 Chestnut St, Boston, MA 02215'}
# {'Order ID': '209992', 'Product': 'Apple Airpods Headphones', 'Quantity Ordered': '1', 'Price Each': '150.0', 'Order Date': '06/21/19 07:51', 'Purchase Address': '207 13th St, Boston, MA 02215'}
# {'Order ID': '209993', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/04/19 18:14', 'Purchase Address': '810 Meadow St, Dallas, TX 75001'}
# {'Order ID': '209994', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/28/19 21:01', 'Purchase Address': '679 Washington St, Boston, MA 02215'}
# {'Order ID': '209995', 'Product': '27in 4K Gaming Monitor', 'Quantity Ordered': '1', 'Price Each': '389.99', 'Order Date': '06/13/19 19:16', 'Purchase Address': '890 Washington St, Austin, TX 73301'}
# {'Order ID': '209996', 'Product': 'Google Phone', 'Quantity Ordered': '1', 'Price Each': '600.0', 'Order Date': '06/13/19 08:21', 'Purchase Address': '965 Johnson St, Austin, TX 73301'}
# {'Order ID': '209997', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/19/19 11:23', 'Purchase Address': '594 Lake St, New York City, NY 10001'}
# {'Order ID': '209998', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/17/19 23:15', 'Purchase Address': '988 Madison St, San Francisco, CA 94016'}
# {'Order ID': '209999', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/16/19 08:37', 'Purchase Address': '949 10th St, Dallas, TX 75001'}
# {'Order ID': '210000', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/06/19 19:17', 'Purchase Address': '534 Park St, Los Angeles, CA 90001'}
# {'Order ID': '210001', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/22/19 12:47', 'Purchase Address': '171 Madison St, Portland, OR 97035'}
# {'Order ID': '210002', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/26/19 13:28', 'Purchase Address': '124 Park St, San Francisco, CA 94016'}
# {'Order ID': '210003', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/26/19 15:09', 'Purchase Address': '928 West St, Boston, MA 02215'}
# {'Order ID': '210004', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/23/19 14:40', 'Purchase Address': '868 8th St, San Francisco, CA 94016'}
# {'Order ID': '210005', 'Product': 'AAA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '2.99', 'Order Date': '06/12/19 19:53', 'Purchase Address': '532 Willow St, Atlanta, GA 30301'}
# {'Order ID': '210006', 'Product': 'Lightning Charging Cable', 'Quantity Ordered': '1', 'Price Each': '14.95', 'Order Date': '06/21/19 19:02', 'Purchase Address': '186 14th St, Boston, MA 02215'}
# {'Order ID': '210007', 'Product': 'iPhone', 'Quantity Ordered': '1', 'Price Each': '700.0', 'Order Date': '06/30/19 09:06', 'Purchase Address': '133 Highland St, Dallas, TX 75001'}
# {'Order ID': '210008', 'Product': '27in FHD Monitor', 'Quantity Ordered': '1', 'Price Each': '149.99', 'Order Date': '06/19/19 00:07', 'Purchase Address': '433 14th St, Portland, OR 97035'}
# {'Order ID': '210009', 'Product': 'Bose SoundSport Headphones', 'Quantity Ordered': '1', 'Price Each': '99.99', 'Order Date': '06/29/19 09:24', 'Purchase Address': '35 West St, Los Angeles, CA 90001'}
# {'Order ID': '210010', 'Product': 'USB-C Charging Cable', 'Quantity Ordered': '1', 'Price Each': '11.95', 'Order Date': '06/01/19 10:56', 'Purchase Address': '469 Pine St, Austin, TX 73301'}
# {'Order ID': '210011', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '1', 'Price Each': '3.84', 'Order Date': '06/13/19 15:10', 'Purchase Address': '615 Forest St, Atlanta, GA 30301'}
# {'Order ID': '210012', 'Product': '34in Ultrawide Monitor', 'Quantity Ordered': '1', 'Price Each': '379.99', 'Order Date': '06/04/19 17:21', 'Purchase Address': '507 1st St, San Francisco, CA 94016'}
# {'Order ID': '210013', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '2', 'Price Each': '3.84', 'Order Date': '06/17/19 17:27', 'Purchase Address': '820 5th St, New York City, NY 10001'}
# {'Order ID': '210014', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/28/19 17:08', 'Purchase Address': '465 Meadow St, Portland, OR 97035'}
# {'Order ID': '210015', 'Product': 'Wired Headphones', 'Quantity Ordered': '1', 'Price Each': '11.99', 'Order Date': '06/06/19 18:12', 'Purchase Address': '559 11th St, Atlanta, GA 30301'}
# {'Order ID': '210016', 'Product': 'AA Batteries (4-pack)', 'Quantity Ordered': '2', 'Price Each': '3.84', 'Order Date': '06/22/19 22:17', 'Purchase Address': '34 14th St, San Francisco, CA 94016'}

# %% [markdown]
# **7)** Determinar productos que se venden juntos y DE A DOS.
# *Se espera*: `Los siguientes productos se venden juntos y de a dos: {x}-{y}, {yy}-{zz} ...`
# **OBS**: Para una misma *orden* se pueden regitrar varios productos.

# %% [markdown]
# **8)** ¿Cuál es el producto más vendido?
# *Se espera*: `El producto más vendido es {x}`

# %% [markdown]
# **9)** ¿Cuál es la relación entre el precio del producto más vendido y el del menos vendido?
# *Se espera:* `El precio del producto más vendido es {n} veces mayor/menor que el producto menos vendido`

# %% [markdown]
# **10)** ¿Cuál es la órden con mayor cantidad de productos?
# *Se espera*: `La órden con mayor cantidad de productos es la número {x}, con {y} productos en total`
